# %% [markdown]
# <a href="https://colab.research.google.com/github/varshitha-2319/parkison-disease-detection_csv-data/blob/main/Parkison_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f84cf705-d111-44ad-adc8-0bb056b731db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f84cf705-d111-44ad-adc8-0bb056b731db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ref                                                               title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# atharvasoundankar/chocolate-sales                                 Chocolate Sales Data 📊🍫                                  14473  2025-03-19 03:51:40.270000          11673        205  1.0
# adilshamim8/student-depression-dataset                            Student Depression Dataset                              467020  2025-03-13 03:12:30.423000           4019         64  1.0
# abdulmalik1518/mobiles-dataset-2025                               Mobiles Dataset (2025)                                   20314  2025-02-18 06:50:24.370000          17409        293  1.0
# ...

# %%
# !kaggle datasets download vikasukani/parkinsons-disease-data-set
# Out:
# Dataset URL: https://www.kaggle.com/datasets/vikasukani/parkinsons-disease-data-set
# License(s): DbCL-1.0

# %%
# !unzip parkinsons-disease-data-set.zip
# Out:
# Archive:  parkinsons-disease-data-set.zip
#   inflating: parkinsons.data

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/parkinsons.data')
df.tail()
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
# ...

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
df.shape
# Out:
# (195, 24)

# %%
#  get the all features except "status"
features = df.loc[:, df.columns != 'status'].values[:, 1:]
labels = df.loc[:, 'status'].values

# %%
df['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
# !pip install catboost

# %% [markdown]
# # DRIVER CODE

# %%
# !pip install xgboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.9/253.9 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 5.1 MB/s eta 0:00:00
# ...

# %%
# !pip install imblearn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.4/238.4 kB 6.5 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade tensorflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 MB 1.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 72.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 104.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 99.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 105.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.2 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade pip
# !pip install numpy pandas catboost xgboost scikit-learn imbalanced-learn tensorflow matplotlib seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 21.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %%
# !pip uninstall -y numpy
# !pip install numpy==1.26.4
# Out:
# Found existing installation: numpy 2.2.4
# Uninstalling numpy-2.2.4:
#   Successfully uninstalled numpy-2.2.4
# ...
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# ...

# %%
import os
import numpy as np
import pandas as pd
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input, Bidirectional, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.callbacks import EarlyStopping

file_path = "/content/parkinsons.data"
df = pd.read_csv(file_path)

print("Dataset Info:\n", df.info())
print("Missing values per column:\n", df.isnull().sum())

features = df.loc[:, df.columns != 'status'].values[:, 1:]
labels = df.loc[:, 'status'].values

smote = SMOTE(sampling_strategy='auto', random_state=42, k_neighbors=3)
X_resampled, y_resampled = smote.fit_resample(features, labels)

X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled
)

catboost_model = CatBoostClassifier(iterations=1000, depth=8, learning_rate=0.03, l2_leaf_reg=5, random_state=42, verbose=0)
catboost_model.fit(X_train, y_train)
catboost_preds = catboost_model.predict(X_test)
catboost_acc = accuracy_score(y_test, catboost_preds)
print(f"CatBoost Accuracy: {catboost_acc:.4f}")

xgb_model = XGBClassifier(n_estimators=1000, learning_rate=0.03, max_depth=8, colsample_bytree=0.8, random_state=42, use_label_encoder=False, eval_metric='logloss')
xgb_model.fit(X_train, y_train)
xgb_preds = xgb_model.predict(X_test)
xgb_acc = accuracy_score(y_test, xgb_preds)
print(f"XGBoost Accuracy: {xgb_acc:.4f}")

rf_model = RandomForestClassifier(n_estimators=1000, max_depth=8, random_state=42)
rf_model.fit(X_train, y_train)
rf_preds = rf_model.predict(X_test)
rf_acc = accuracy_score(y_test, rf_preds)
print(f"RandomForest Accuracy: {rf_acc:.4f}")

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_reshaped = X_train_scaled.reshape(X_train_scaled.shape[0], 1, X_train_scaled.shape[1])
X_test_reshaped = X_test_scaled.reshape(X_test_scaled.shape[0], 1, X_test_scaled.shape[1])

inputs = Input(shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2]))
x = Bidirectional(LSTM(256, return_sequences=True))(inputs)
x = BatchNormalization()(x)
x = Bidirectional(LSTM(128, return_sequences=False))(x)
x = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
x = BatchNormalization()(x)
x = Dense(64, activation='relu', kernel_regularizer=l2(0.001))(x)
x = Dropout(0.3)(x)
x = Dense(1, activation='sigmoid')(x)

bilstm_model = Model(inputs, x)
bilstm_model.compile(optimizer='adamw', loss='binary_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
bilstm_model.fit(X_train_reshaped, y_train, epochs=20, batch_size=32, validation_split=0.1, callbacks=[early_stopping])

bilstm_preds = bilstm_model.predict(X_test_reshaped)
bilstm_preds = (bilstm_preds > 0.5).astype(int).flatten()
bilstm_acc = accuracy_score(y_test, bilstm_preds)
print(f"BiLSTM Accuracy: {bilstm_acc:.4f}")

ensemble_preds = (0.25 * catboost_preds + 0.25 * xgb_preds + 0.25 * rf_preds + 0.25 * bilstm_preds).round().astype(int)
ensemble_acc = accuracy_score(y_test, ensemble_preds)
print(f"Hybrid Model Accuracy: {ensemble_acc:.4f}")
print("Hybrid Model Classification Report:\n", classification_report(y_test, ensemble_preds))
print("Confusion Matrix:\n", confusion_matrix(y_test, ensemble_preds))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
from catboost import CatBoostClassifier

catboost_model = CatBoostClassifier(
    iterations=5000,           # More iterations with early stopping
    depth=10,                  # Deeper trees for better learning
    learning_rate=0.05,        # Slightly higher learning rate
    l2_leaf_reg=4,             # Reduce overfitting with L2 regularization
    random_state=42,
    loss_function='Logloss',
    eval_metric='Accuracy',
    boosting_type='Ordered',   # More stable boosting
    border_count=254,         # More precise feature splits
    bagging_temperature=0.8,  # Introduce randomness for better generalization
    auto_class_weights='Balanced',  # Handle class imbalance
    od_type='Iter',           # Enable early stopping
    od_wait=50,               # Stop training if no improvement in 50 iterations
    verbose=200
)

catboost_model.fit(X_train, y_train, eval_set=(X_test, y_test), early_stopping_rounds=50)
catboost_preds = catboost_model.predict(X_test)
catboost_acc = accuracy_score(y_test, catboost_preds)

print(f"Improved CatBoost Accuracy: {catboost_acc:.4f}")
# Out:
# 0:	learn: 0.9532450	test: 0.9322083	best: 0.9322083 (0)	total: 137ms	remaining: 11m 26s
# Stopped by overfitting detector  (50 iterations wait)
#
# bestTest = 0.9492283288
# bestIteration = 14
#
# Shrink model to first 15 iterations.
# Improved CatBoost Accuracy: 0.9492

# %%
# !pip install lightgbm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 52.4 MB/s eta 0:00:00
# ...

# %%
import os
import numpy as np
import pandas as pd
from lightgbm import LGBMClassifier, early_stopping
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

file_path = "/content/parkinsons.data"
df = pd.read_csv(file_path)

features = df.loc[:, df.columns != 'status'].values[:, 1:]
labels = df.loc[:, 'status'].values

smote = SMOTE(sampling_strategy='auto', random_state=42, k_neighbors=3)
X_resampled, y_resampled = smote.fit_resample(features, labels)

X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled
)

lgbm_model = LGBMClassifier(
    boosting_type='gbdt',
    num_leaves=64,        # Higher leaves for better splits
    max_depth=10,         # Deep trees for better learning
    learning_rate=0.02,   # Slower learning rate for stability
    n_estimators=3000,    # More iterations with early stopping
    reg_alpha=0.1,        # L1 regularization
    reg_lambda=0.2,       # L2 regularization
    colsample_bytree=0.8, # Feature sampling
    subsample=0.8,        # Row sampling
    random_state=42
)

# Use early_stopping callback
# Removed verbose from fit and kept it only in early_stopping
lgbm_model.fit(X_train, y_train,
              eval_set=[(X_test, y_test)],
              callbacks=[early_stopping(stopping_rounds=100, verbose=200)])
lgbm_preds = lgbm_model.predict(X_test)
lgbm_acc = accuracy_score(y_test, lgbm_preds)

print(f"LightGBM Accuracy: {lgbm_acc:.4f}")
# Out:
# [LightGBM] [Info] Number of positive: 118, number of negative: 117
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000193 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1687
# [LightGBM] [Info] Number of data points in the train set: 235, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.502128 -> initscore=0.008511
# [LightGBM] [Info] Start training from score 0.008511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# # **FINAL**

# %%
# !pip install optuna
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 52.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 602.4/602.4 kB 28.1 MB/s eta 0:00:00
# ...

# %%
import optuna
from catboost import CatBoostClassifier
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold, train_test_split
import pandas as pd

file_path = "/content/parkinsons.data"
df = pd.read_csv(file_path)

features = df.loc[:, df.columns != 'status'].values[:, 1:]
labels = df.loc[:, 'status'].values
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(features, labels) # Changed X, y to features, labels

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

def objective(trial):
    params = {
        "iterations": trial.suggest_int("iterations", 1000, 4000),
        "depth": trial.suggest_int("depth", 6, 16),
        "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.2),
        "l2_leaf_reg": trial.suggest_loguniform("l2_leaf_reg", 1e-5, 100),
        "border_count": trial.suggest_int("border_count", 32, 255),
        "bagging_temperature": trial.suggest_float("bagging_temperature", 0.0, 1.0),
        "random_strength": trial.suggest_float("random_strength", 1e-9, 10),
        "auto_class_weights": 'Balanced',  # Enhances class balancing
        "random_state": 42,
        "verbose": 0
    }

    acc_scores = []

    for train_idx, val_idx in skf.split(X_resampled, y_resampled):
        X_train, X_val = X_resampled[train_idx], X_resampled[val_idx]
        y_train, y_val = y_resampled[train_idx], y_resampled[val_idx]

        model = CatBoostClassifier(**params, early_stopping_rounds=100)
        model.fit(X_train, y_train, eval_set=(X_val, y_val), verbose=0)
        preds = model.predict(X_val)
        acc_scores.append(accuracy_score(y_val, preds))

    return sum(acc_scores) / len(acc_scores)

# Create and optimize the study
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)

# Best parameters found
best_params = study.best_params
print("Best Params:", best_params)

# Train final model with best parameters
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

optimized_catboost = CatBoostClassifier(**best_params, random_state=42, verbose=0)
optimized_catboost.fit(X_train, y_train)
opt_preds = optimized_catboost.predict(X_test)

# Final accuracy after SMOTE, Cross-Validation, and Tuning
opt_acc = accuracy_score(y_test, opt_preds)
print(f"Optimized CatBoost Accuracy with SMOTE & CV: {opt_acc:.4f}")
# Out:
# [I 2025-03-26 09:31:35,476] A new study created in memory with name: no-name-5e43ed18-a04c-461e-a732-c9200c07b770
# <ipython-input-12-1ed4e06e6fb5>:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "learning_rate": trial.suggest_loguniform("learning_rate", 0.001, 0.2),
# <ipython-input-12-1ed4e06e6fb5>:23: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   "l2_leaf_reg": trial.suggest_loguniform("l2_leaf_reg", 1e-5, 100),
# ...

# %%
import optuna
from catboost import CatBoostClassifier
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold, train_test_split
import pandas as pd
df = pd.read_csv('parkinsons.data')

# Extract Features (Same Preprocessing as Before)
features = df.loc[:, df.columns != 'status'].values[:, 1:]

# Load the Best Model
optimized_catboost = CatBoostClassifier(**best_params, random_state=42, verbose=0)
optimized_catboost.fit(X_train, y_train)  # Ensure the model is trained

# Example New Data (Replace with Actual Values)
new_data = np.array([[202.26600, 211.60400, 197.07900, 0.00180, 0.000009, 0.00093, 0.00107, 0.00278,
    0.00954, 0.08500, 0.00469, 0.00606, 0.00719, 0.01407, 0.00072, 32.68400,
    0.368535, 0.742133, -7.695734, 0.178540, 1.544609, 0.056141]])

# Make Prediction
prediction = optimized_catboost.predict(new_data)

# Output Prediction
if prediction[0] == 1:
    print("Predicted: Parkinson's Disease (PD)")
else:
    print("Predicted: Healthy")

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, opt_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=[0, 1], yticklabels=[0, 1])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - Optimized CatBoost')
plt.show()

# %%
# ✅ Sample input data (from the provided row)
sample_input = [
    119.99200, 157.30200, 74.99700, 0.00784, 0.00007, 0.00370, 0.00554, 0.01109,
    0.04374, 0.42600, 0.02182, 0.03130, 0.02971, 0.06545, 0.02211, 21.03300,
    0.414783, 0.815285, -4.813031, 0.266482, 2.301442, 0.284654
]

# ✅ Convert input to numpy array and scale it
sample_data = np.array([sample_input])
scaled_data = scaler.transform(sample_data)

# ✅ Reshape for BiLSTM input
reshaped_data = scaled_data.reshape(scaled_data.shape[0], 1, scaled_data.shape[1])

# ✅ Predict using individual models
catboost_prediction = optimized_catboost.predict(sample_data)[0]
xgb_prediction = xgb_model.predict(sample_data)[0]
rf_prediction = rf_model.predict(sample_data)[0]


# ✅ Hybrid Model Prediction (Weighted Voting)
final_prediction = round(0.25 * catboost_prediction +
                         0.25 * xgb_prediction +
                         0.25 * rf_prediction )

# ✅ Display result
if final_prediction == 1:
    print("\n🔴 The model predicts that this person is likely to have Parkinson's disease.")
else:
    print("\n🟢 The model predicts that this person is unlikely to have Parkinson's disease.")

# %%
import numpy as np

# ✅ Define feature names for user input
features = [
    "MDVP:Fo(Hz)", "MDVP:Fhi(Hz)", "MDVP:Flo(Hz)", "MDVP:Jitter(%)", "MDVP:Jitter(Abs)",
    "MDVP:RAP", "MDVP:PPQ", "Jitter:DDP", "MDVP:Shimmer", "MDVP:Shimmer(dB)",
    "Shimmer:APQ3", "Shimmer:APQ5", "MDVP:APQ", "Shimmer:DDA", "NHR", "HNR",
    "RPDE", "DFA", "spread1", "spread2", "D2", "PPE"
]

# ✅ Collect user input for all features
user_input = []
print("\nEnter the following details:")
for feature in features:
    value = float(input(f"{feature}: "))
    user_input.append(value)

# ✅ Convert input to numpy array and scale it
sample_data = np.array([user_input])
scaled_data = scaler.transform(sample_data)

# ✅ Reshape for BiLSTM input
reshaped_data = scaled_data.reshape(scaled_data.shape[0], 1, scaled_data.shape[1])

# ✅ Predict using individual models
catboost_prediction = optimized_catboost.predict(sample_data)[0]
xgb_prediction = xgb_model.predict(sample_data)[0]
rf_prediction = rf_model.predict(sample_data)[0]
87
8


# ✅ Hybrid Model Prediction (Weighted Voting)
final_prediction = round(0.25 * catboost_prediction +
                         0.25 * xgb_prediction +
                         0.25 * rf_prediction )

# ✅ Display result
if final_prediction == 1:
    print("\n🔴 The model predicts that this person is likely to have Parkinson's disease.")
else:
    print("\n🟢 The model predicts that this person is unlikely to have Parkinson's disease.")

# %%
# ✅ Sample input data (new row)
sample_input = [
    202.26600, 211.60400, 197.07900, 0.00180, 0.000009, 0.00093, 0.00107, 0.00278,
    0.00954, 0.08500, 0.00469, 0.00606, 0.00719, 0.01407, 0.00072, 32.68400,
    0.368535, 0.742133, -7.695734, 0.178540, 1.544609, 0.056141
]

# ✅ Convert input to numpy array and scale it
sample_data = np.array([sample_input])
scaled_data = scaler.transform(sample_data)

# ✅ Reshape for BiLSTM input
reshaped_data = scaled_data.reshape(scaled_data.shape[0], 1, scaled_data.shape[1])

# ✅ Predict using individual models
catboost_prediction = optimized_catboost.predict(sample_data)[0]
xgb_prediction = xgb_model.predict(sample_data)[0]
rf_prediction = rf_model.predict(sample_data)[0]


# ✅ Hybrid Model Prediction (Weighted Voting)
final_prediction = round(0.25 * catboost_prediction +
                         0.25 * xgb_prediction +
                         0.25 * rf_prediction)

# ✅ Display result
if final_prediction == 1:
    print("\n🔴 The model predicts that this person is likely to have Parkinson's disease.")
else:
    print("\n🟢 The model predicts that this person is unlikely to have Parkinson's disease.")

# %%
import pickle

# Save CatBoost model
pickle.dump(optimized_catboost, open('catboost_model.pkl', 'wb'))
pickle.dump(xgb_model, open('xgb_model.pkl', 'wb'))
pickle.dump(rf_model, open('rf_model.pkl', 'wb'))
pickle.dump(scaler, open('scaler.pkl', 'wb'))

# %%
# !pip install optuna

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.utils.validation import check_X_y
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Define function to create a Keras model
def create_nn():
    model = Sequential([
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Wrap Keras model using KerasClassifier
nn_wrapper = KerasClassifier(model=create_nn, epochs=10, batch_size=32, verbose=0)

# Define base models
base_models = [
    ('lgbm', LGBMClassifier(n_estimators=2000, learning_rate=0.01, max_depth=12, random_state=42)),
    ('xgb', XGBClassifier(n_estimators=1500, learning_rate=0.015, max_depth=10, eval_metric='logloss', random_state=42)),
    ('rf', RandomForestClassifier(n_estimators=1000, max_depth=12, random_state=42))
]

# Use StackingClassifier with wrapped Keras model
stacking_clf = StackingClassifier(estimators=base_models, final_estimator=nn_wrapper)

# Train the stacking model
stacking_clf.fit(X_train, y_train)

# Evaluate
stacked_preds = stacking_clf.predict(X_test)
stacked_acc = accuracy_score(y_test, stacked_preds)

print(f"Stacked Model (with NN) Accuracy: {stacked_acc:.4f}")

# %%
from sklearn.ensemble import StackingClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

# Define base models
base_models = [
    ('lgbm', LGBMClassifier(n_estimators=2000, learning_rate=0.01, max_depth=12, random_state=42)),
    ('xgb', XGBClassifier(n_estimators=1500, learning_rate=0.015, max_depth=10, eval_metric='logloss', random_state=42)),
    ('rf', RandomForestClassifier(n_estimators=1000, max_depth=12, random_state=42))
]

# Use CatBoost as meta-model
meta_model = CatBoostClassifier(iterations=1000, depth=8, learning_rate=0.03, l2_leaf_reg=5, verbose=0, random_state=42)

# Define stacking classifier
stacking_clf = StackingClassifier(estimators=base_models, final_estimator=meta_model)

# Train and evaluate
stacking_clf.fit(X_train, y_train)
stacked_preds = stacking_clf.predict(X_test)
stacked_acc = accuracy_score(y_test, stacked_preds)

print(f"Stacked Model with CatBoost Meta-Model Accuracy: {stacked_acc:.4f}")

# %%
# Use a more powerful CatBoost as the meta-model
meta_model = CatBoostClassifier(
    iterations=1500,  # Increased from 1000 to 1500
    depth=10,  # Increased from 8 to 10
    learning_rate=0.02,  # Slightly reduced to stabilize learning
    l2_leaf_reg=8,  # Increased regularization to prevent overfitting
    verbose=0,
    random_state=42
)

# %%
# Updated base models with fine-tuned hyperparameters
base_models = [
    ('lgbm', LGBMClassifier(n_estimators=2500, learning_rate=0.007, max_depth=14, num_leaves=60, random_state=42)),
    ('xgb', XGBClassifier(n_estimators=1800, learning_rate=0.012, max_depth=12, eval_metric='logloss', subsample=0.8, colsample_bytree=0.8, random_state=42)),
    ('rf', RandomForestClassifier(n_estimators=1200, max_depth=15, min_samples_split=4, random_state=42))
]

# %%
from sklearn.ensemble import ExtraTreesClassifier

# Add Extra Trees to the base models
base_models.append(('et', ExtraTreesClassifier(n_estimators=1200, max_depth=15, random_state=42)))

# %%
from sklearn.ensemble import VotingClassifier

# Soft voting classifier (averaging probabilities)
voting_clf = VotingClassifier(estimators=base_models, voting='soft')
voting_clf.fit(X_train, y_train)

voting_preds = voting_clf.predict(X_test)
voting_acc = accuracy_score(y_test, voting_preds)

print(f"Soft Voting Classifier Accuracy: {voting_acc:.4f}")

# %%
meta_model = CatBoostClassifier(
    iterations=1000,  # Reduce iterations to 1000 (from 1500)
    depth=8,  # Reduce depth (from 10 to 8)
    learning_rate=0.03,  # Increase learning rate for better convergence
    l2_leaf_reg=5,  # Reduce regularization (from 8 to 5)
    verbose=0,
    random_state=42
)

# %%
base_models = [
    ('lgbm', LGBMClassifier(n_estimators=1200, learning_rate=0.01, max_depth=10, num_leaves=40, random_state=42)),
    ('xgb', XGBClassifier(n_estimators=1200, learning_rate=0.015, max_depth=9, eval_metric='logloss', subsample=0.8, colsample_bytree=0.8, random_state=42)),
    ('rf', RandomForestClassifier(n_estimators=800, max_depth=10, min_samples_split=5, random_state=42))
]

# %%
from sklearn.linear_model import LogisticRegression

meta_model = LogisticRegression(max_iter=1000)  # Simple and robust
stacking_clf = StackingClassifier(estimators=base_models, final_estimator=meta_model)
stacking_clf.fit(X_train, y_train)

stacked_preds = stacking_clf.predict(X_test)
stacked_acc = accuracy_score(y_test, stacked_preds)

print(f"Stacked Model Accuracy (Logistic Regression Meta-Model): {stacked_acc:.4f}")

# %%
from sklearn.ensemble import VotingClassifier

voting_clf = VotingClassifier(estimators=base_models, voting='soft')
voting_clf.fit(X_train, y_train)

voting_preds = voting_clf.predict(X_test)
voting_acc = accuracy_score(y_test, voting_preds)

print(f"Soft Voting Classifier Accuracy: {voting_acc:.4f}")

# %%
voting_clf = VotingClassifier(estimators=base_models, voting='hard')
voting_clf.fit(X_train, y_train)

voting_preds = voting_clf.predict(X_test)
voting_acc = accuracy_score(y_test, voting_preds)

print(f"Hard Voting Classifier Accuracy: {voting_acc:.4f}")

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'lgbm__n_estimators': [1000, 1500, 2000],
    'lgbm__max_depth': [10, 12, 15],
    'xgb__n_estimators': [1000, 1500, 2000],
    'xgb__max_depth': [8, 10, 12],
    'rf__n_estimators': [500, 800, 1000],
    'rf__max_depth': [8, 10, 12]
}

grid = GridSearchCV(voting_clf, params, cv=3, scoring='accuracy', n_jobs=-1)
grid.fit(X_train, y_train)

print("Best Parameters:", grid.best_params_)
print("Best Accuracy:", grid.best_score_)

# %%
meta_model = LGBMClassifier(n_estimators=500, learning_rate=0.05, max_depth=6, random_state=42)
stacking_clf = StackingClassifier(estimators=base_models, final_estimator=meta_model)

stacking_clf.fit(X_train, y_train)
stacked_preds = stacking_clf.predict(X_test)
stacked_acc = accuracy_score(y_test, stacked_preds)

print(f"Stacked Model Accuracy (LGBM Meta-Model): {stacked_acc:.4f}")
